# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("FFCC79B01604Concrete.csv")

data.Units
# Out:
# 0     62.9375
# 1     62.9375
# 2     62.9375
# 3     63.0500
# 4     63.0500
#        ...
# 95    66.4250
# 96    66.5375
# 97    66.6500
# 98    66.8750
# 99    67.1000
# Name: Units, Length: 100, dtype: float64

# %%
time_units = pd.DataFrame(data, columns=['TimeStamp','Units'])
time_units
# Out:
#                TimeStamp    Units
# 0   9/10/2018 7:43:43 PM  62.9375
# 1   9/10/2018 8:14:07 PM  62.9375
# 2   9/10/2018 8:44:31 PM  62.9375
# 3   9/10/2018 9:14:55 PM  63.0500
# 4   9/10/2018 9:45:21 PM  63.0500
# ..                   ...      ...
# 95  9/12/2018 7:39:18 PM  66.4250
# 96  9/12/2018 8:09:35 PM  66.5375
# 97  9/12/2018 8:39:51 PM  66.6500
# 98  9/12/2018 9:10:03 PM  66.8750
# 99  9/12/2018 9:40:12 PM  67.1000
#
# [100 rows x 2 columns]

# %%
time_units.plot()
plt.title('Da Plot')
plt.show()

# %%
with plt.xkcd():
    plt.figure()
    time_units.plot()
    plt.title('Da Plot')
# Out:
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
import matplotlib.dates as md
import matplotlib.ticker as ticker

data0 = pd.read_csv("http://206.189.227.139:8181/Query/Latest/1000.csv?Units=Standard&Timezone=EST5EDT&SensorID=FFACA2A71605")
data1 = pd.read_csv("http://206.189.227.139:8181/Query/Latest/1000.csv?Units=Standard&Timezone=EST5EDT&SensorID=FFD6A0B01604")

plt.figure(figsize=(16,10))
plt.plot(data0.Units, 'k--')
plt.plot(data1.Units, 'g-')
plt.grid()
plt.ylabel('Temperature')
plt.legend(('Concrete', 'Green Space'))
